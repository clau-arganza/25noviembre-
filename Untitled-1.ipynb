# %%
A=[3,9,-2,7,10,0,4,5]   print(max(A))  print(min(A))
Izquierda= [3,9,-2,7] max1=9 min1=-2
Derecha=[10,0,4,5]  max2=10   min2=0

def max_min(arr):
    if len(arr)==1
        return arr[0],arr[0]
    
    mid =len(arr)//2
    max1,min1 = max_min(arr[:mid])
    max2,min2= max_min(arr[mid:])

    return max(max1,max2), min(min1,min2)
